# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
filename = 'text8.zip'
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3082, 12, 6, 195, 2, 3135, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span) #a word sequence
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  #print(buffer)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    #print('target => {0}'.format(target))
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1) #WHILE until target not in targer_to_avoid
      targets_to_avoid.append(target)
      
      #print('targets_to_avoid => {0}'.format(targets_to_avoid))
      
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index]) # move the window, renew the buffer
    data_index = (data_index + 1) % len(data)
    #print('target => {0}'.format(target))
    #print('targets_to_avoid => {0}'.format(targets_to_avoid))
    #print(buffer)
  
  #following 3 lines change Skip-gram to CBOW delete them to change back

  #temp = batch
  #batch = labels.reshape(batch_size)
  #labels = temp.reshape(batch_size,1)

  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'originated', 'term', 'a', 'originated', 'term', 'of', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 300
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 15 # How many words to consider left and right.
num_skips = 30 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.115508
# Nearest to had: redesigned, ibm, wis, systema, confined, prescribes, hillsborough, amyotrophic,
# Nearest to or: superstars, genes, masses, fianc, overarching, wollaston, isometric, limburgish,
# Nearest to these: peloponnese, ave, reconciled, jacobitism, tana, prana, bricks, evers,
# Nearest to at: shrublands, objects, nw, gchq, curse, inverness, stuart, levitt,
# Nearest to have: environmentalists, imprints, rattle, resentment, aunts, moose, bremen, hinayana,
# Nearest to during: virginal, overture, integrating, einsatzgruppen, munch, sergei, wojty, somewhat,
# Nearest to in: jo, gambler, push, papyri, oscillations, scripts, subfamilies, overthrow,
# Nearest to will: indicates, glycolipids, satrap, frazier, odin, spelled, loki, leena,
# Nearest to not: kilocalories, sturdy, freaks, luton, animators, carolus, nacional, cubewanos,
# Nearest to between: misery, jesu, simplicius, forefathers, andromeda, coliseum, messerschmitt, imam,
# Nearest to also: hunyadi, bends, sloti, utah, longitude, windmill, foundational, paratime,
# Nearest to from: rovers, whereof, comit, fourteenth, gene, lodgings, grub, alu,
# Nearest to new: youssef, intern, rouen, abortive, hemlock, tank, beads, lublin,
# Nearest to this: ethane, leading, forum, symbolised, ftp, kildare, cics, exploratory,
# Nearest to he: umayyad, ghz, gpo, brow, eroding, threaten, vue, treasure,
# Nearest to they: pq, hauge, geometry, leadership, chancery, nanny, tedious, weapons,
# Average loss at step 2000: 4.688819
# Average loss at step 4000: 4.270604
# Average loss at step 6000: 4.179620
# Average loss at step 8000: 4.071731
# Average loss at step 10000: 4.042810
# Nearest to had: methylene, redesigned, hillsborough, ibm, deng, essential, radiating, piranha,
# Nearest to or: of, are, to, as, a, that, for, activator,
# Nearest to these: evers, arose, adequate, jacobitism, trypanosoma, alertness, ave, tana,
# Nearest to at: his, lil, pioneer, smile, agm, algorithmic, plight, levitt,
# Nearest to have: mangrove, guerrillas, in, below, that, jutland, environmentalists, areas,
# Nearest to during: overture, virginal, wojty, somewhat, drones, probable, munch, naming,
# Nearest to in: to, and, as, one, an, of, this, that,
# Nearest to will: odin, evangelium, indulging, attributed, indicates, aliphatic, outlaws, acceptor,
# Nearest to not: as, homeopaths, that, the, thickness, drawbacks, drives, settled,
# Nearest to between: delegated, benedict, it, comedienne, capablanca, granularity, revolutionaries, authorities,
# Nearest to also: foundational, aol, windmill, sloti, crumb, for, as, more,
# Nearest to from: s, and, one, it, on, in, to, cramps,
# Nearest to new: intern, youssef, hemlock, tank, lublin, peshitta, marcy, cessation,
# Nearest to this: in, to, and, of, that, one, forum, an,
# Nearest to he: his, was, s, best, almonds, baud, dans, trainers,
# Nearest to they: or, mean, departed, salts, weapons, are, hauge, leadership,
# Average loss at step 12000: 4.101770
# Average loss at step 14000: 4.080263
# Average loss at step 16000: 4.025610
# Average loss at step 18000: 3.961496
# Average loss at step 20000: 3.995775
# Nearest to had: was, tau, took, mastery, agamemnon, muharram, methylene, his,
# Nearest to or: are, this, with, it, is, but, not, an,
# Nearest to these: their, rarely, favourite, ave, reconciled, adequate, silvia, meltzer,
# Nearest to at: soils, downright, unready, was, spock, west, emissaries, war,
# Nearest to have: are, it, or, alessandri, guillermo, with, has, jc,
# Nearest to during: einsatzgruppen, integrating, ways, overture, somewhat, malpighi, wojty, anaconda,
# Nearest to in: the, of, two, south, s, and, from, dervish,
# Nearest to will: odin, indicates, outlaws, suffer, indulging, evangelium, attributed, acceptor,
# Nearest to not: but, or, they, this, unexpected, it, if, disproved,
# Nearest to between: stromata, delegated, sil, capablanca, adventures, comedienne, esterification, revolutionaries,
# Nearest to also: with, as, nabba, steeped, see, zooplankton, used, progressed,
# Nearest to from: on, was, s, in, subsidence, greece, fractal, constantine,
# Nearest to new: intern, youssef, growling, primal, tank, peshitta, hemlock, probable,
# Nearest to this: or, it, with, not, is, leaves, kinderhook, most,
# Nearest to he: his, was, newspapers, astana, batavii, chordal, reaffirm, timbre,
# Nearest to they: not, wing, bronze, all, hired, sweyn, leadership, instead,
# Average loss at step 22000: 4.033804
# Average loss at step 24000: 3.996262
# Average loss at step 26000: 3.927793
# Average loss at step 28000: 4.021699
# Average loss at step 30000: 3.898542
# Nearest to had: was, he, have, consilience, his, took, gabbro, to,
# Nearest to or: magyar, as, for, maurya, marca, an, who, leaf,
# Nearest to these: cinq, censure, their, cetus, other, reconciled, asymptotically, such,
# Nearest to at: was, for, by, on, increasingly, unready, he, thanking,
# Nearest to have: not, had, they, their, gwen, has, several, alessandri,
# Nearest to during: ways, integrating, somewhat, overture, limehouse, einsatzgruppen, wojty, spell,
# Nearest to in: the, and, of, to, by, a, on, apollo,
# Nearest to will: odin, attributed, indicates, evangelium, suffer, outlaws, sunk, adad,
# Nearest to not: they, have, be, to, who, for, it, were,
# Nearest to between: delegated, frankenchrist, rn, sun, pete, troop, capablanca, benedict,
# Nearest to also: used, dalton, see, legislate, other, or, reconstructionism, various,
# Nearest to from: by, modulus, on, radio, impressions, greek, rupp, disintegrate,
# Nearest to new: intern, mindanao, higher, primal, cryonics, growling, probable, on,
# Nearest to this: that, be, sputtering, not, it, locksmiths, pitfalls, peninsula,
# Nearest to he: his, was, who, had, that, when, him, to,
# Nearest to they: not, their, have, were, wing, carbonaceous, subsidies, do,
# Average loss at step 32000: 3.855367
# Average loss at step 34000: 3.833407
# Average loss at step 36000: 3.857065
# Average loss at step 38000: 3.894514
# Average loss at step 40000: 3.970963
# Nearest to had: his, he, warriors, lunations, keane, gabbro, was, oxidized,
# Nearest to or: be, such, a, has, not, that, are, may,
# Nearest to these: can, are, many, other, not, they, asymptotically, eukaryotic,
# Nearest to at: keyser, this, first, new, s, priming, nei, emissaries,
# Nearest to have: not, has, been, variants, as, only, it, literally,
# Nearest to during: spell, somewhat, world, war, euskadi, ways, integrating, limehouse,
# Nearest to in: and, the, of, to, one, nine, a, with,
# Nearest to will: odin, be, indulging, attributed, indicates, why, sunk, acceptor,
# Nearest to not: but, more, they, have, to, be, many, or,
# Nearest to between: delegated, stromata, fanning, troop, moderates, sunnah, pete, weakness,
# Nearest to also: see, as, used, legislate, expendable, or, frescoes, barisan,
# Nearest to from: to, and, the, with, on, by, its, an,
# Nearest to new: mindanao, at, crowley, south, chandra, ethnicities, probable, higher,
# Nearest to this: it, is, at, there, precursors, day, which, on,
# Nearest to he: his, was, him, had, eyes, who, wink, koreans,
# Nearest to they: not, are, subsidies, their, be, these, when, them,
# Average loss at step 42000: 3.923518
# Average loss at step 44000: 3.981017
# Average loss at step 46000: 3.879683
# Average loss at step 48000: 3.912052
# Average loss at step 50000: 3.943393
# Nearest to had: were, his, he, after, but, equilibrium, with, later,
# Nearest to or: all, as, with, are, is, psychologists, include, flurry,
# Nearest to these: other, were, solve, their, many, stripe, some, okavango,
# Nearest to at: up, while, oro, subtypes, wishbone, having, that, there,
# Nearest to have: has, been, that, who, abductions, lar, augmenting, dirty,
# Nearest to during: world, war, ways, wojty, firmus, borda, kelley, marched,
# Nearest to in: and, of, a, to, the, as, other, from,
# Nearest to will: can, odin, sunk, indulging, laramie, attributed, rodin, homicidal,
# Nearest to not: but, if, this, interquartile, only, order, is, that,
# Nearest to between: delegated, tuxedo, fanning, riigikogu, hospitality, troop, menagerie, sergius,
# Nearest to also: for, other, from, see, used, well, but, most,
# Nearest to from: and, also, marino, with, in, omaha, reaper, tli,
# Nearest to new: probable, tract, unfamiliar, galatian, freshmen, disrupting, jobs, portsmouth,
# Nearest to this: for, there, that, not, tramways, also, an, on,
# Nearest to he: his, him, when, that, had, who, lucius, pompey,
# Nearest to they: their, but, prevail, did, are, muslims, platt, bonhomme,
# Average loss at step 52000: 3.953737
# Average loss at step 54000: 3.922912
# Average loss at step 56000: 3.950336
# Average loss at step 58000: 3.961921
# Average loss at step 60000: 3.870228
# Nearest to had: he, at, was, after, were, that, his, has,
# Nearest to or: with, as, a, generally, have, timbre, apteryx, where,
# Nearest to these: other, eukaryotic, more, they, turpin, are, such, excitable,
# Nearest to at: he, that, was, with, had, time, for, in,
# Nearest to have: has, that, not, other, but, i, some, there,
# Nearest to during: world, war, at, after, he, controlling, messerschmitt, competitiveness,
# Nearest to in: a, and, with, of, to, as, for, at,
# Nearest to will: can, odin, categorized, swat, sunk, notepad, hee, worcestershire,
# Nearest to not: but, they, that, are, so, if, this, only,
# Nearest to between: tuxedo, this, usemodwiki, granularity, into, from, is, nippur,
# Nearest to also: external, other, known, smooth, these, settling, turismo, leads,
# Nearest to from: its, an, at, it, this, on, with, profession,
# Nearest to new: york, freshmen, city, state, safed, vojt, village, frustrating,
# Nearest to this: is, for, that, a, it, not, an, has,
# Nearest to he: was, his, him, had, at, who, when, after,
# Nearest to they: their, not, are, so, all, but, these, with,
# Average loss at step 62000: 3.898904
# Average loss at step 64000: 3.978649
# Average loss at step 66000: 3.960029
# Average loss at step 68000: 3.980529
# Average loss at step 70000: 3.888163
# Nearest to had: later, his, when, been, after, only, while, however,
# Nearest to or: not, are, order, for, from, any, shula, used,
# Nearest to these: some, are, many, their, not, asymptotically, other, eukaryotic,
# Nearest to at: its, it, when, for, some, on, but, omaha,
# Nearest to have: many, are, has, some, neisse, more, their, any,
# Nearest to during: war, world, year, over, ludwig, after, became, controlling,
# Nearest to in: the, and, of, to, a, that, multilateral, one,
# Nearest to will: may, would, categorized, demoralized, when, homicidal, if, no,
# Nearest to not: but, to, be, or, some, if, it, a,
# Nearest to between: out, granularity, they, into, hayling, if, expressways, through,
# Nearest to also: its, system, omaha, extraordinary, assuming, while, belongings, for,
# Nearest to from: or, classifications, graphs, jury, may, plethora, coupling, milanese,
# Nearest to new: for, jovi, gotham, york, nuclear, dresden, hundreds, system,
# Nearest to this: it, is, on, that, because, to, a, an,
# Nearest to he: his, him, her, was, llewellyn, dysplasia, himself, died,
# Nearest to they: not, their, such, are, some, between, but, reconciled,
# Average loss at step 72000: 3.989918
# Average loss at step 74000: 3.947549
# Average loss at step 76000: 3.946318
# Average loss at step 78000: 3.885149
# Average loss at step 80000: 3.684488
# Nearest to had: been, has, during, after, later, this, until, was,
# Nearest to or: are, all, their, which, there, have, called, also,
# Nearest to these: their, are, other, many, most, all, have, linen,
# Nearest to at: its, between, about, but, into, over, distinguishes, that,
# Nearest to have: has, many, their, are, there, such, or, other,
# Nearest to during: war, after, had, over, in, world, death, women,
# Nearest to in: a, the, was, of, by, after, and, during,
# Nearest to will: would, may, if, when, can, be, sunk, demoralized,
# Nearest to not: but, they, however, by, there, those, that, only,
# Nearest to between: into, at, north, its, through, that, of, south,
# Nearest to also: see, list, its, which, many, british, or, other,
# Nearest to from: were, bc, pineal, oppressed, through, identifier, fragmented, which,
# Nearest to new: york, time, first, conceits, then, referencing, flensburg, scone,
# Nearest to this: that, has, been, it, more, had, however, its,
# Nearest to he: his, him, after, i, when, before, who, never,
# Nearest to they: not, are, were, may, such, reconciled, their, there,
# Average loss at step 82000: 3.963331
# Average loss at step 84000: 3.939681
# Average loss at step 86000: 3.807249
# Average loss at step 88000: 3.934197
# Average loss at step 90000: 3.895934
# Nearest to had: been, at, cultivate, made, addington, s, during, until,
# Nearest to or: not, these, may, they, are, be, as, that,
# Nearest to these: they, are, were, as, there, have, those, or,
# Nearest to at: took, had, during, barrymore, minimally, wumpus, from, for,
# Nearest to have: who, those, been, there, were, that, some, their,
# Nearest to during: war, world, stuff, women, quays, at, until, ess,
# Nearest to in: and, for, a, that, the, as, UNK, from,
# Nearest to will: would, may, can, like, if, when, sunk, they,
# Nearest to not: it, that, to, or, but, be, a, this,
# Nearest to between: only, which, may, order, fuse, granularity, daniell, mee,
# Nearest to also: an, other, not, that, this, associated, tsuba, for,
# Nearest to from: and, by, be, UNK, in, that, as, to,
# Nearest to new: york, cherubim, vojt, penderecki, accomplices, reissue, mcintosh, massively,
# Nearest to this: it, an, be, by, not, for, would, a,
# Nearest to he: him, his, a, on, in, by, s, an,
# Nearest to they: were, these, them, their, often, some, do, not,
# Average loss at step 92000: 3.900259
# Average loss at step 94000: 3.937901
# Average loss at step 96000: 3.899116
# Average loss at step 98000: 3.943684
# Average loss at step 100000: 3.915955
# Nearest to had: he, was, the, after, has, been, his, of,
# Nearest to or: may, plasmid, delhi, orders, other, which, coasts, centrality,
# Nearest to these: are, other, many, more, sram, such, overlord, cede,
# Nearest to at: he, and, after, when, roberto, his, into, to,
# Nearest to have: has, some, that, their, but, other, did, been,
# Nearest to during: war, world, after, the, ii, its, fates, over,
# Nearest to in: the, of, to, and, a, one, new, nine,
# Nearest to will: would, can, must, kick, may, you, yasser, washington,
# Nearest to not: may, that, they, did, bounding, only, have, treeless,
# Nearest to between: according, mauritius, having, fuse, sideband, timescales, ingenuity, impeccable,
# Nearest to also: UNK, syrups, see, japanese, on, approaching, an, blitter,
# Nearest to from: UNK, s, on, by, and, of, under, socialist,
# Nearest to new: york, in, several, and, the, had, years, australia,
# Nearest to this: it, that, of, being, was, which, have, death,
# Nearest to he: his, him, after, had, when, was, at, that,
# Nearest to they: their, were, some, are, not, them, those, have,

# %%
num_points = 600

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(30,30))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
